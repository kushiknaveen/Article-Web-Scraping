# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://content.guardianapis.com/technology/artificialintelligenceai?&api-key=f2d609fe-e32b-442b-838d-8b02ab589a75&type=article&page=1"

# %%
response=requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
x=response.json()

# %%
x
# Out:
# {'response': {'status': 'ok',
#   'userTier': 'developer',
#   'total': 2162,
#   'startIndex': 1,
#   'pageSize': 10,
#   'currentPage': 1,
#   'pages': 217,
#   'orderBy': 'newest',
#   'tag': {'id': 'technology/artificialintelligenceai',
#    'type': 'keyword',
#    'sectionId': 'technology',
#    'sectionName': 'Technology',
#    'webTitle': 'Artificial intelligence (AI)',
#    'webUrl': 'https://www.theguardian.com/technology/artificialintelligenceai',
#    'apiUrl': 'https://content.guardianapis.com/technology/artificialintelligenceai'},
#   'results': [{'id': 'books/2024/mar/27/inside-the-inaugural-womens-prize-for-nonfiction-shortlist',
#     'type': 'article',
#     'sectionId': 'books',
#     'sectionName': 'Books',
#     'webPublicationDate': '2024-03-27T18:00:11Z',
#     'webTitle': 'Electric, poignant, exquisitely written: inside the inaugural Women’s prize for nonfiction shortlist',
# ...

# %%
#Number of articles
len(x['response']['results'])
# Out:
# 10

# %%
# check for url's
web_urls = [item['webUrl'] for item in x['response']['results']]

for url in web_urls:
    print(url)
    print("\n")
# Out:
# https://www.theguardian.com/books/2024/mar/27/inside-the-inaugural-womens-prize-for-nonfiction-shortlist
#
#
# https://www.theguardian.com/technology/2024/mar/27/ai-apocalypse-could-take-away-almost-8m-jobs-in-uk-says-report
#
#
# https://www.theguardian.com/technology/2024/mar/26/ai-beer-taste-better-belgium-scientists
#
#
# https://www.theguardian.com/technology/2024/mar/25/san-jose-homelessness-ai-detection
#
#
# https://www.theguardian.com/world/2024/mar/25/ai-hedgehog-populations-pioneering-uk-project
#
#
# https://www.theguardian.com/games/2024/mar/23/game-developer-conference-layoffs-ai-support
#
#
# https://www.theguardian.com/books/2024/mar/23/code-dependent-by-madhumita-murgia-review-understanding-the-human-impacts-of-ai
#
#
# https://www.theguardian.com/world/2024/mar/21/danish-man-found-guilty-of-fraudulently-profiting-from-music-streaming-royalties
#
#
# ...

# %%
import os
from datetime import datetime

# Create a folder with the current date and time format
current_datetime = datetime.now()
folder_name = current_datetime.strftime('%m.%d.%Y')

if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# %%
BeautifulSoup(requests.get(url).text, 'html.parser')
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <!-- Hello there, HTML enthusiast! -->
# <!-- DCR commit hash 8420a9305297cfcd8c9e8b7a852bf931cf4b1c9e -->
# <title>Georgia lawmakers are using an AI deepfake video to try to ban political deepfakes | Georgia | The Guardian</title>
# <meta content="A bill working its way through state legislature seeks to stop use of AI tech in politics – but some far-right activists are opposed" name="description"/>
# <link href="https://www.theguardian.com/us-news/2024/mar/20/georgia-ai-ban-political-campaigns-deepfakes" rel="canonical"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width,minimum-scale=1,initial-scale=1" name="viewport"/>
# <meta content="#052962" name="theme-color">
# <link href="https://assets.guim.co.uk/static/frontend/manifest.json" rel="manifest"/>
# <link href="https://assets.guim.co.uk/static/frontend/icons/homescreen/apple-touch-icon.svg" rel="apple-touch-icon" sizes="any"/>
# ...

# %%
def save_content_to_file(url, folder, filename):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
 
            with open(os.path.join(folder, filename), 'w', encoding='utf-8') as file:
                for header in soup.find_all(['h1']):
                    file.write("Title: " + header.text + '\n'*3)
                for paragraph in soup.find_all('p'):
                    file.write(paragraph.text + '\n')
        else:
            print("Failed to retrieve the page:", url)
    except Exception as e:
        print("An error occurred:", e)

# Loop through the list of web URLs and save content to separate text files
for index, url in enumerate(web_urls):
    filename = f'article_{index}.txt'  # Create a unique filename for each article
    save_content_to_file(url, folder_name, filename)

print("Executed Perfectly")
# Out:
# Executed Perfectly
